# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
from pathlib import Path
import os


# 10s，75
x1=[["0",627.36,161.119,0.910459,909.552,274.777,0.0864944],
     ["1",572.539,210.157,0.813187,917.37,331.602,0.0907124],
     ["2",572.508,210.103,0.8876,862.516,349.225,0.078235],
     ["3",551.014,296.358,0.857782],
     ["4",554.992,384.521,0.885566],
     ["5",576.463,210.18,0.645885,972.234,327.674,0.0738445],
     ["6",598.074,304.178,0.803809],
     ["7",652.859,353.155,0.898289],
     ["8",576.536,378.639,0.662798],
     ["9",582.306,380.588,0.664169],
     ["10",631.354,496.179,0.776269],
     ["11",647.023,613.701,0.829276],
     ["12",572.604,378.649,0.545786],
     ["13",549.06,496.117,0.780424],
     ["14",502.065,609.807,0.810867],
     ["15",619.652,149.335,0.964018,895.824,266.925,0.0648517],
     ["16",921.292,266.921,0.0856306],
     ["17",592.143,149.389,0.940528],
     ["18",927.149,270.882,0.0675114],
     ["19",549.066,635.192,0.762443],
     ["20",543.141,631.302,0.694735],
     ["21",490.221,619.578,0.77315],
     ["22",697.955,629.392,0.702084],
     ["23",686.227,633.321,0.74763],
     ["24",637.217,627.41,0.795493]]

# %%
test=pd.DataFrame(x1)
test.columns=["Point", "X", "Y", "confidence ", "X", "Y", "confidence "]
test
# Out:
#    Point        X        Y  confidence         X        Y  confidence
# 0      0  627.360  161.119     0.910459  909.552  274.777     0.086494
# 1      1  572.539  210.157     0.813187  917.370  331.602     0.090712
# 2      2  572.508  210.103     0.887600  862.516  349.225     0.078235
# 3      3  551.014  296.358     0.857782      NaN      NaN          NaN
# 4      4  554.992  384.521     0.885566      NaN      NaN          NaN
# 5      5  576.463  210.180     0.645885  972.234  327.674     0.073844
# 6      6  598.074  304.178     0.803809      NaN      NaN          NaN
# 7      7  652.859  353.155     0.898289      NaN      NaN          NaN
# 8      8  576.536  378.639     0.662798      NaN      NaN          NaN
# 9      9  582.306  380.588     0.664169      NaN      NaN          NaN
# 10    10  631.354  496.179     0.776269      NaN      NaN          NaN
# 11    11  647.023  613.701     0.829276      NaN      NaN          NaN
# ...

# %%
for i in range(0,9):
    plt.scatter(test[2][i], test[1][i],color='Blue')
for i in range(9,15):
    plt.scatter(test[2][i], test[1][i],color='Red')
for i in range(15,19):
    plt.scatter(test[2][i], test[1][i],color='Yellow')
for i in range(19,25):
    plt.scatter(test[2][i], test[1][i],color='Black')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEng
#   '16': [919.337, 264.984, 0.084944],
#   '17': [598.025, 143.534, 0.928365],
#   '18': [925.209, 268.924, 0.0673546],
#   '19': [605.915, 627.377, 0.365502],
#   '20': [603.919, 627.357, 0.296725],
# ...

# %%
keypoints_parameter_right_x=[]
keypoints_parameter_right_y=[]
keypoints_parameter_left_x=[]
keypoints_parameter_left_y=[]
path="C:/Users/Jack/OneDrive/桌面/openpose/examples/media/test/10s/json"
files= os.listdir(path)
s=len(files)

for i in range(0,s):
    str_files=str(files[i])
    with open(str_files) as f:
        data = json.load(f)
        keypoints = data.get("part_candidates")
        
        keypoints_parameter_right = keypoints[0].get("11")
        keypoints_parameter_left = keypoints[0].get("14")
  
        #右腳
        plt.scatter(keypoints_parameter_right[0], keypoints_parameter_right[1],color='Blue')
        #左腳
        plt.scatter(keypoints_parameter_left[0], keypoints_parameter_left[1],color='Red')
              
        keypoints_parameter_right_x.append(keypoints_parameter_right[0])
        keypoints_parameter_right_y.append(keypoints_parameter_right[1])
        keypoints_parameter_left_x.append(keypoints_parameter_left[0])
        keypoints_parameter_left_y.append(keypoints_parameter_left[1])

# %%
plt.title('Right_Ankle')
plt.show(plt.plot(keypoints_parameter_right_x, 'bo-', label='o'))
plt.title('Left_Ankle')
plt.show(plt.plot(keypoints_parameter_left_x, 'ro-', label='o'))

# %%
plt.plot(keypoints_parameter_right_x, 'b-', label='o')
plt.plot(keypoints_parameter_left_x, 'r-', label='o')

# %%
len(keypoints_parameter_right_x)
# Out:
# 317

# %%
for i in range(0,s):
    print(i,keypoints_parameter_right_x[i])
# Out:
# 0 605.846
# 1 625.471
# 2 654.9
# 3 664.601
# 4 664.6
# 5 660.763
# 6 652.904
# 7 639.22
# 8 631.342
# 9 631.344
# 10 623.495
# 11 615.661
# 12 599.928
# 13 592.104
# 14 592.106
# 15 580.401
# 16 572.643
# 17 556.821
# 18 549.009
# 19 549.01
# 20 539.232
# 21 531.432
# 22 513.772
# 23 505.963
# 24 505.965
# 25 500.048
# 26 494.266
# 27 502.043
# 28 507.977
# 29 507.98
# 30 517.73
# 31 531.449
# 32 564.759
# 33 572.616
# 34 572.613
# 35 598.02
# 36 617.616
# 37 647.06
# 38 650.885
# 39 650.886
# 40 646.992
# 41 639.217
# 42 625.419
# 43 615.706
# 44 615.705
# 45 607.849
# 46 599.989
# 47 584.35
# 48 572.558
# 49 572.542
# 50 566.625
# 51 554.954
# 52 539.304
# 53 533.328
# 54 533.327
# 55 523.521
# 56 515.759
# 57 498.172
# 58 492.297
# 59 492.295
# 60 492.221
# 61 492.31
# 62 509.823
# 63 515.807
# 64 517.66
# 65 529.523
# 66 545.118
# 67 572.629
# 68 600.037
# 69 600.024
# 70 615.694
# 71 633.346
# 72 656.858
# 73 652.965
# 74 652.966
# 75 647.023
# 76 639.204
# 77 623.517
# ...

# %%
keypoints_t1 = 0
state1 = 0
state2 = 0
step_count = 0

# for index in range(0,s):
#     keypoints_t1 = keypoints_parameter_right_x[index]
#     if index <= s:
#         keypoints_t2 = keypoints_parameter_right_x[index+1]
#     print("==new==")
#     print(keypoints_t2)
#     print("==old==")
#     print(keypoints_t1)
    
#     if keypoints_t2 > keypoints_t1:
#         print("往前")
#     else:
#         print("往後")
    
#     if keypoints_t2 > keypoints_t1:
#         state1 = state1 + 1
#         print("t2>t1，state+1")
#         print("state1累計:",state1)
#         if state1 >= 3 :
#             if keypoints_t1 < keypoints_t2:
#                 state2=state2+1
#                 print("state2累計:",state2)
#                 if state2 >=3:
#                     step_count=step_count+1
#                     state1 = 0
#                     state2 = 0
#                     print("歸零，步數+1")
#     print("點:",index+1)            
#     print("累積步數:",step_count,"\n")


# continuous=0
# for index in range(0,s):
#     keypoints_t1 = keypoints_parameter_right_x[index]
#     if index <= s:
#         keypoints_t2 = keypoints_parameter_right_x[index+1]
    
#     if keypoints_t2>keypoints_t1:
#         continuous = continuous + 1
#         state2 = state2 + 1
#         state1 = 0
#         if state2 >= 3 and state1 >= 3:
#             step_count = step_count + 1
     
#     elif keypoints_t1>keypoints_t2:
#         continuous = continuous + 1
#         state1 = state1 + 1
#         if state1 >= 3:
#             state2 = 0
            
#     if keypoints_t2 > keypoints_t1:
#         print("往前")
#     if keypoints_t1 > keypoints_t2:
#         print("往後")

# case = 0      
# continuous=0
# for index in range(0,s):
#     keypoints_t1 = keypoints_parameter_right_x[index]
#     if index <= s:
#         keypoints_t2 = keypoints_parameter_right_x[index+1]
        
#     if keypoints_t2>keypoints_t1:
#         state2 = state2 + 1
#         if state2 >= 2:
#             case = 0

#     if keypoints_t2 < keypoints_t1:
#         state1 = state1 + 1
#         if state1 >= 2:
#             case = 1
    
#     if case = 0:
#         continuous = continuous + 1
#         if keypoints_t2 < keypoints_t1:
            
# case = 0      
# continuous=0
# for index in range(0,s):
#     keypoints_t1 = keypoints_parameter_right_x[index]
#     if index <= s:
#         keypoints_t2 = keypoints_parameter_right_x[index+1]
    
#     if case == 0:
#         if keypoints_t2>keypoints_t1:
#             state2 = state2 + 1
#             if state2 >= 2:
#                 case = 1

#         if keypoints_t2 < keypoints_t1:
#             state1 = state1 + 1
#             if state1 >= 2:
#                 case = 1
    
#     elif case == 1: 
#         if keypoints_t2 < keypoints_t1:
#             continuous = continuous + 1
#         if continuous>= 2:
#             step_count = step_count + 1
#             continuous = 0
#             case = 0
#             state2 = 0
#             print(step_count)
